# %% [markdown]
# # Chapter 2: Drawing with 2D Vectors

# %%
# %load_ext autoreload
# %autoreload 2
from vector_drawing import *
import matplotlib.pyplot as plt
from math import sqrt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2.1 Picturing 2D Vectors

# %% [markdown]
# 本章节底层使用matplotlib进行绘图，下面是其基本用法。该函数库对外暴露接口对向量进行了封装。

# %%
xp = [0, 1, 3]
yp = [1, 2, 5]
plt.scatter(xp, yp)
plt.plot(xp, yp)
plt.arrow(1, 3, 2, 1, head_width=0.2, head_length=0.4)
plt.xlim(-1, 6)
plt.ylim(-1, 6)
plt.grid(True)

# %%
dino_vectors = [
    (6, 4), (3, 1), (1, 2), (-1, 5), (-2, 5), (-3, 4), (-4, 4),
    (-5, 3), (-5, 2), (-2, 2), (-5, 1), (-4, 0), (-2, 1), (-1, 0), (0, -3),
    (-1, -4), (1, -4), (2, -3), (1, -2), (3, -1), (5, 1)
]

draw(
    Points(*dino_vectors)
)

# %%
draw(
    Points(*dino_vectors),
    Segment((6, 4), (3, 1))
)

# %% [markdown]
# **EXERCISE:** Draw the dinosaur with the dots connected by constructing a `Polygon` object with the `dino_vectors` as its vertices.

# %%
draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors)
)

# %%
draw(Points([2, -2]), Arrow([2, -2]))

# %% [markdown]
# **EXERCISE** Draw the vectors `[(x,x**2) for x in range(-10,11)]` as points (dots) using the draw function.  What is the result?

# %%
draw(
    Points(*[(x, x ** 2) for x in range(-10, 11)]),
    grid=(1, 10),
    nice_aspect_ratio=False  # don't require x scale to match y scale
)

# %% [markdown]
# # Plane Vector Arithmetic

# %%
def add(v1, v2):
    return v1[0] + v2[0], v1[1] + v2[1]


T = (-1.5, -2.5)
dino_vectors2 = [add(v, T) for v in dino_vectors]

draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
)

# %%
arrows = [
    Arrow(add(v, T), v, color=black) for v in dino_vectors
]

draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
    *arrows
)

# %% [markdown]
# 下面是作者的实现，利用了线段、列表推导和zip语法；*号的元组展开也特别有意思

# %%
arrows = [Segment(tip, tail, color=black) for (tip, tail) in
          zip(dino_vectors2, dino_vectors)]

draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
    *arrows
)

# %% [markdown]
# ## Vector components and lengths

# %%
draw(
    Arrow([4, 3]),
    Arrow([4, 0], color=blue),
    Arrow([4, 3], [4, 0], color=green)
)

# %%
def length(v):
    return sqrt(v[0] ** 2 + v[1] ** 2)

# %% [markdown]
# ## Subtraction, displacement, and distance

# %%
draw(
    Points((2, 2), (-1, 3)),
    Segment((2, 2), (-1, 3), color=red)
)

# %% [markdown]
# **MINI-PROJECT:** You can add any number of vectors together by summing all of their $x$-coordinates and all of their $y$-coordinates.  For instance the four-fold sum (1,2) + (2,4) + (3,6) + (4,8) has $x$-component 1 + 2 + 3 + 4 = 10 and $y$-component 2 + 4 + 6 + 8 = 20, making the result (10,20).  Implement a revised add function that takes any number of vectors as arguments.

# %%
def add(*vector_list):
    return sum([v[0] for v in vector_list]), sum([v[1] for v in vector_list])

# %% [markdown]
# **EXERCISE:** Write a function translate(translation, vectors) that takes in a translation vector and a list of input vectors and returns a list of the input vectors all translated by the translation vector. For instance, `translate((1,1), [(0,0), (0,1,), (-3,-3)])` should return `[(1,1),(1,2),(-2,-2)]`.

# %%
def translate(translation, vector_list):
    return [add(translation, v) for v in vector_list]


translate((1, 1), [(0, 0), (0, 1,), (-3, -3)])
# Out:
# [(1, 1), (1, 2), (-2, -2)]

# %% [markdown]
# **MINI-PROJECT:** Write a Python function using vector addition to show 100 simultaneous and non-overlapping copies of the dinosaur.  This shows the power of computer graphics: imagine how tedious it would be to specify all 2,100 coordinate pairs by hand!

# %%
def hundred_dinos():
    translations = [(12 * x, 10 * y)
                    for x in range(-5, 5)
                    for y in range(-5, 5)]
    dinos = [Polygon(*translate(t, dino_vectors), color=blue)
             for t in translations]
    draw(*dinos, grid=None, axes=None, origin=None)

# %%
hundred_dinos()

# %% [markdown]
# **EXERCISE:** What vector in the dino_vectors list has the longest length?  Use the Python length function to compute the answer quickly.

# %%
max(dino_vectors, key=length)
(6, 4)
# Out:
# (6, 4)

# %% [markdown]
# **EXERCISE:** Suppose a vector $\vec{w}$ has coordinates $(2 ,3)$.  What are the approximate coordinates of the scalar multiple $\pi \cdot \vec{w}$?  Draw an approximation of the original vector and the new vector.

# %%
from math import sqrt, pi

w = (sqrt(2), sqrt(3))
w_scaled = (pi * sqrt(2), pi * sqrt(3))

# %%
w_scaled
# Out:
# (4.442882938158366, 5.441398092702653)

# %%
draw(
    Arrow(w_scaled, color=red),
    Arrow(w, color=black)
)

# %% [markdown]
# **EXERCISE:** Write a python function `scale(s, v)` that multiplies the input vector `v` by the input scalar `s`.

# %%
def scale(scalar, v):
    return [scalar * v[0], scalar * v[1]]

# %% [markdown]
# **MINI-PROJECT:** Suppose $\vec{u} = (-1,1)$ and $\vec{v} = (1,1)$ and suppose $r$ and $s$ are real numbers.  Specifically, let’s assume $-1 < r < 1$ and $-3 < s < 3$.
#
# Where are the possible points on the plane where the vector $r \cdot \vec{u} + s \cdot \vec{v}$ could end up?
#
# Note: the order of operations is the same for vectors as it is for numbers: we assume scalar multiplication is carried out first, and then vector addition (unless parentheses specify otherwise).

# %%
from random import uniform

u = (-1, 1)
v = (1, 1)


def random_r():
    return uniform(-3, 3)


def random_s():
    return uniform(-1, 1)


possibilities = [add(scale(random_r(), u), scale(random_s(), v))
                 for i in range(0, 500)]
draw(
    Points(*possibilities)
)

# %% [markdown]
# **EXERCISE:** Write a Python function `subtract(v1,v2)` that returns the result of `v1` minus `v2`, where the inputs and output are tuples of coordinates as we’ve seen so far.

# %%
def subtract(v1, v2):
    return [v1[0] - v2[0], v1[1] - v2[1]]

# %% [markdown]
# **EXERCISE:** Write a Python function `distance(v1,v2)` that returns the distance between two input vectors (noting that the subtract function from the previous exercise already gives the displacement).
#
# Write another Python function `perimeter(vectors)` that takes a list of vectors as an argument and returns the sum of distances from each vector to the next, including the distance from the last vector to the first.  What is the perimeter of the polygon defined by `dino_vectors`?

# %%
def distance(v1, v2):
    return length(subtract(v1, v2))

# %%
def perimeter(vector_list):
    distances = [distance(vector_list[i], vector_list[(i + 1) % len(vector_list)])
                 for i in range(0, len(vector_list))]
    return sum(distances)

# %%
# sanity check with a square
square = [(1, 0), (1, 1), (0, 1), (0, 0)]
draw(Polygon(*square), grid=(0.2, 0.2), axes=None)

# %%
# should be 1+1+1+1=4
perimeter(square)
# Out:
# 4.0

# %%
perimeter(dino_vectors)
# Out:
# 44.77115093694563

# %% [markdown]
# **MINI-PROJECT:** Let $\vec{u}$ be the vector $(1,2)$.  Suppose there is another vector, $\vec{v}$, with positive integer coordinates $(n, m)$ such that $n > m$, and having distance $13$ from $\vec{u}$.  What is the displacement from $\vec{u}$ to $\vec{v}$?  Hint: you can use Python to search for the vector $\vec{v}$.

# %% [markdown]
# **SOLUTION:** We only need to search possible integer pairs (n,m) where n is within 13 units of 1 and m is within 13 units of -1.

# %%
for n in range(-12, 15):
    for m in range(-14, 13):
        if distance((n, m), (1, -1)) == 13 and n > m > 0:
            print((n, m))
# Out:
# (13, 4)

# %% [markdown]
# # Angles and trigonometry in the plane

# %% [markdown]
# ## Radians and trigonometry in python

# %%
from math import tan

tan(45)  # tangent of 45 radians, not degrees
# Out:
# 1.6197751905438615

# %%
from math import tan, pi

tan(pi / 4)  # now this is the tangent of pi/4 radians = 45 degrees
# Out:
# 0.9999999999999999

# %%
from math import sin, cos


def to_cartesian(polar_vector):
    length_value, angle_value = polar_vector[0], polar_vector[1]
    return length_value * cos(angle_value), length_value * sin(angle_value)

# %%
# Verify that 5 units @ 37 degrees takes us to (4,3)
angle = 37 * pi / 180
to_cartesian((5, angle))
# Out:
# (3.993177550236464, 3.0090751157602416)

# %%
from math import asin

sin(1)
# Out:
# 0.8414709848078965

# %%
asin(0.8414709848078965)
# Out:
# 1.0

# %%
# trying to find an angle with sin = 3/sqrt(13)
from math import sqrt

asin(3 / sqrt(13))
# Out:
# 0.9827937232473292

# %%
from math import acos

acos(-2 / sqrt(13))
# Out:
# 2.1587989303424644

# %%
cos(2.1587989303424644)
# Out:
# -0.5547001962252293

# %%
-2 / sqrt(13)
# Out:
# -0.5547001962252291

# %%
sin(2.1587989303424644)
# Out:
# 0.8320502943378436

# %%
3 / sqrt(13)
# Out:
# 0.8320502943378437

# %%
from math import atan2

atan2(3, -2)
# Out:
# 2.158798930342464

# %%
def to_polar(vector):
    x, y = vector[0], vector[1]
    angle_value = atan2(y, x)
    return length(vector), angle_value

# %%
to_polar((1, 0))
# Out:
# (1.0, 0.0)

# %%
to_polar((-2, 3))
# Out:
# (3.605551275463989, 2.158798930342464)

# %% [markdown]
# **EXERCISE:** Confirm that the vector given by cartesian coordinates (-1.34,2.68) has length approximately 3, as expected.

# %%
length((-1.34, 2.68))
# Out:
# 2.9963310898497184

# %% [markdown]
# **EXERCISE:** What is $116.57^\circ$ in radians?  Use Python to compute the tangent of this angle, and confirm that it is close to $-2$ as we saw above.

# %% [markdown]
# **SOLUTION:** $116.57^\circ · (1 \text{rad} / 57.296^\circ) = 2.035 \text{rad}.$

# %%
116.57 * (pi / 180)
# Out:
# 2.03453030904979

# %%
tan(116.57 * (pi / 180))
# Out:
# -1.9995682083189954

# %%
tan(2.035)
# Out:
# -1.9972227673316139

# %% [markdown]
# **EXERCISE:** Locate the angle $10\pi/6$.  Do you expect the values of $\cos(10\pi/6)$ and $\sin(10\pi/6)$ to be positive or negative?  Use Python to calculate their values and confirm.

# %% [markdown]
# **SOLUTION:** The angle $\pi/6$ is one third of a quarter-turn, so $10\pi/6$ is less than a quarter turn short of a full rotation.  This means that it points "down and to the right".  The cosine should be positive and the sine should be negative, since distance in this direction corresponds with positive horizontal displacement and negative vertical displacement.

# %%
sin(10 * pi / 6)
# Out:
# -0.8660254037844386

# %%
cos(10 * pi / 6)
# Out:
# 0.5

# %% [markdown]
# **EXERCISE:** The following list comprehension creates 1000 points in polar coordinates.

# %%
polar_coords = [(cos(5 * x * pi / 500.0), 2 * pi * x / 1000.0) for x in range(0, 1000)]
print(polar_coords)
# Out:
# [(1.0, 0.0), (0.9995065603657316, 0.006283185307179587), (0.9980267284282716, 0.012566370614359173), (0.99556196460308, 0.01884955592153876), (0.9921147013144779, 0.025132741228718346), (0.9876883405951378, 0.031415926535897934), (0.9822872507286887, 0.03769911184307752), (0.9759167619387474, 0.0439822971502571), (0.9685831611286311, 0.05026548245743669), (0.9602936856769431, 0.05654866776461628), (0.9510565162951535, 0.06283185307179587), (0.9408807689542255, 0.06911503837897544), (0.9297764858882515, 0.07539822368615504), (0.9177546256839811, 0.08168140899333463), (0.9048270524660196, 0.0879645943005142), (0.8910065241883679, 0.09424777960769379), (0.8763066800438636, 0.10053096491487339), (0.8607420270039436, 0.10681415022205297), (0.8443279255020151, 0.11309733552923255), (0.8270805742745618, 0.11938052083641214), (0.8090169943749475, 0.12566370614359174), (0.7901550123756904, 0.13194689145077132), (0.7705132427757891, 0.13823007675795088), (0.7501110696304596, 0.1445132620651305), (0.7289686274214116, 0.15079644737231007), (0.7071067811865476, 0.15707963267948966), (0.6845471059286887, 0.16336281798666927), (0.6613118653236519, 0.16964600329384882), (0.6374239897486897, 0.1759291886010284), (0.6129070536529766, 0.18221237390820802), (0.5877852522924732, 0.18849555921538758), (0.5620833778521306, 0.19477874452256716), (0.5358267949789967, 0.20106192982974677), (0.5090414157503714, 0.20734511513692636), (0.4817536741017154, 0.21362830044410594), (0.4539904997395468, 0.21991148575128552), (0.42577929156507266, 0.2261946710584651), (0.3971478906347808, 0.2324778563656447), (0.36812455268467786, 0.23876104167282428), (0.3387379202452915, 0.24504422698000386), (0.30901699437494745, 0.25132741228718347), (0.2789911060392293, 0.257610597594363), (0.24868988716485474, 0.26389378290154264), (0.21814324139654268, 0.2701769682087222), (0.18738131458572452, 0.27646015351590175), (0.15643446504023092, 0.2827433388230814), (0.12533323356430426, 0.289026524130261), (0.09410831331851428, 0.29530970943744056), (0.06279051952931351, 0.30159289474462014), (0.031410759078128396, 0.3078760800517997), (6.123233995736766e-17, 0.3141592653589793), (-0.03141075907812828, 0.3204424506661589), (-0.06279051952931318, 0.32672563597333854), (-0.0941083133185144, 0.33300882128051806), (-0.12533323356430415, 0.33929200658769765), (-0.1564344650402308, 0.3455751918948773), (-0.1873813145857246, 0.3518583772020568), (-0.21814324139654256, 0.3581415625092364), (-0.24868988716485463, 0.36442474781641604), (-0.2789911060392294, 0.37070793312359557), (-0.30901699437494734, 0.37699111843077515), (-0.33873792024529137, 0.3832743037379548), (-0.368124552684678, 0.3895574890451343), (-0.3971478906347807, 0.39584067435231396), (-0.42577929156507277, 0.40212385965949354), (-0.45399049973954675, 0.40840704496667307), (-0.481753674101715, 0.4146902302738527), (-0.5090414157503713, 0.4209734155810323), (-0.5358267949789964, 0.4272566008882119), (-0.5620833778521306, 0.43353978619539146), (-0.587785252292473, 0.43982297150257105), (-0.6129070536529763, 0.44610615680975063), (-0.6374239897486896, 0.4523893421169302), (-0.661311865323652, 0.4586725274241098), (-0.6845471059286884, 0.4649557127312894), (-0.7071067811865475, 0.47123889803846897), (-0.7289686274214117, 0.47752208334564855), (-0.7501110696304596, 0.48380526865282814), (-0.7705132427757891, 0.4900884539600077), (-0.7901550123756904, 0.49637163926718736), (-0.8090169943749473, 0.5026548245743669), (-0.8270805742745617, 0.5089380098815465), (-0.8443279255020151, 0.515221195188726), (-0.8607420270039435, 0.5215043804959058), (-0.8763066800438637, 0.5277875658030853), (-0.8910065241883678, 0.5340707511102648), (-0.9048270524660194, 0.5403539364174444), (-0.9177546256839811, 0.546637121724624), (-0.9297764858882515, 0.5529203070318035), (-0.9408807689542253, 0.5592034923389833), (-0.9510565162951535, 0.5654866776461628), (-0.9602936856769431, 0.5717698629533423), (-0.9685831611286311, 0.578053048260522), (-0.975916 ...

# %% [markdown]
# In Python code, convert them to cartesian coordinates, and connect them in a closed loop with line segments to draw a picture.

# %%
polar_coords_2 = [(cos(x * pi / 100.0), 2 * pi * x / 1000.0) for x in range(0, 1000)]
vectors = [to_cartesian(p) for p in polar_coords_2]
draw(Polygon(*vectors, color=green))

# %% [markdown]
# **EXERCISE:** Find the angle to get to the point (-2,3) by “guess-and-check”.

# %%
# we want to make guesses between pi/2 and pi
pi, pi / 2
# Out:
# (3.141592653589793, 1.5707963267948966)

# %%
tan(1.8)
# Out:
# -4.286261674628062

# %%
tan(2.5)
# Out:
# -0.7470222972386602

# %%
tan(2.2)
# Out:
# -1.3738230567687948

# %%
tan(2.1)
# Out:
# -1.7098465429045078

# %%
tan(2.15)
# Out:
# -1.5289797578045667

# %%
tan(2.16)
# Out:
# -1.4961035416162771

# %%
tan(2.155)
# Out:
# -1.5124173422757465

# %%
tan(2.156)
# Out:
# -1.50913489938793

# %%
tan(2.157)
# Out:
# -1.505862348872722

# %%
tan(2.158)
# Out:
# -1.5025996395625056

# %%
# we conclude the angle is between 2.158 and 2.159.
tan(2.159)
# Out:
# -1.4993467206361923

# %% [markdown]
# **EXERCISE:**  Find another point in the plane with the same tangent as $\theta$, that is $-3/2$.  Use Python’s implementation of the arc-tangent function, `math.atan`, to find the value of this angle.

# %%
from math import atan

# %%
atan(-3 / 2)
# Out:
# -0.982793723247329

# %%
# this is the direction to the point (2,-3).  
# tan(-3/2) = tan(-1.5) = tan(3/-2)
draw(Arrow((2, -3)), Points((2, -3)))

# %% [markdown]
# **EXERCISE:** Without using Python, what are polar coordinates corresponding to the cartesian coordinates $(1,1)$ and $(1,-1)$?  Once you’ve found the answers, use to_polar to check your work.
#
# **SOLUTION:** The answers should be $(\sqrt{2},\pi/4)$ and $(\sqrt{2},-\pi/4)$.

# %%
to_polar((1, 1))
# Out:
# (1.4142135623730951, 0.7853981633974483)

# %%
to_polar((1, -1))
# Out:
# (1.4142135623730951, -0.7853981633974483)

# %%
#compare to
(sqrt(2), pi / 4)
# Out:
# (1.4142135623730951, 0.7853981633974483)

# %%
(sqrt(2), -pi / 4)
# Out:
# (1.4142135623730951, -0.7853981633974483)

# %% [markdown]
# # Transforming collections of vectors

# %%
rotation_angle = pi / 4

dino_polar = [to_polar(v) for v in dino_vectors]
dino_rotated_polar = [(l, angle + rotation_angle) for l, angle in dino_polar]
dino_rotated = [to_cartesian(p) for p in dino_rotated_polar]

draw(
    Polygon(*dino_vectors, color=gray),
    Polygon(*dino_rotated, color=red)
)

# %% [markdown]
# **EXERCISE:** Create a `rotate(angle, vectors)` function which takes an array of input vectors in cartesian coordinates and returns them by the specified angle (counterclockwise or clockwise according to whether the angle is positive or negative).

# %%
def rotate(angle_value, vector_list):
    polars = [to_polar(v) for v in vector_list]
    return [to_cartesian((l, a + angle_value)) for l, a in polars]

# %% [markdown]
# ## Combining vector transformations

# %%
new_dino = translate((8, 8), rotate(5 * pi / 3, dino_vectors))
draw(Polygon(*new_dino))

# %% [markdown]
# **EXERCISE:** Create a function `polygon(n)` which returns cartesian coordinates of a regular $n$-sided polygon (that is, having all angles and side lengths equal).  For instance, `polygon(7)` could produce vectors defining a heptagon.

# %%
def regular_polygon(num):
    return [to_cartesian((1, 2 * pi * k / num)) for k in range(0, num)]

# %%
draw(
    Polygon(*regular_polygon(7))
)

# %%
draw(
    Polygon(*regular_polygon(12))
)
